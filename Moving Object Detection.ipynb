# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\rohin\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rohin\anaconda3\lib\site-packages (from opencv-python) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imutlis
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement imutlis
# ERROR: No matching distribution found for imutlis

# %%
pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\rohin\anaconda3\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import time
import imutils

cam = cv2.VideoCapture(0)
time.sleep(1)

firstFrame=None
area = 500
#count = 0

while True:
    _,img = cam.read()
    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21, 21), 0)
    if firstFrame is None:
            firstFrame = gaussianImg
            continue
    imgDiff = cv2.absdiff(firstFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)
    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL,
            cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    for c in cnts:
            if cv2.contourArea(c) < area:
                    continue
            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            #count = count +  1
            text = "Moving Object detected"
    print(text)
    cv2.putText(img, text, (10, 20),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    cv2.imshow("cameraFeed",img)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Normal
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
# Moving Object detected
